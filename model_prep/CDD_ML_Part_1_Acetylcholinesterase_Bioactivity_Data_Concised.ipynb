# %% [markdown]
# # **Bioinformatics Project - Computational Drug Discovery [Part 1] Download Bioactivity Data (Concised version)**
#
# Chanin Nantasenamat
#
# [*'Data Professor' YouTube channel*](http://youtube.com/dataprofessor)
#
# In this Jupyter notebook, we will be building a real-life **data science project** that you can include in your **data science portfolio**. Particularly, we will be building a machine learning model using the ChEMBL bioactivity data.
#
# In **Part 1**, we will be performing Data Collection and Pre-Processing from the ChEMBL Database.
#
# Note for this Concised Version:
# * Redundant code cells were deleted.
# * Code cells for saving files to Google Drive has been deleted.
#
# ---

# %% [markdown]
# ## **ChEMBL Database**
#
# The [*ChEMBL Database*](https://www.ebi.ac.uk/chembl/) is a database that contains curated bioactivity data of more than 2 million compounds. It is compiled from more than 76,000 documents, 1.2 million assays and the data spans 13,000 targets and 1,800 cells and 33,000 indications.
# [Data as of March 25, 2020; ChEMBL version 26].

# %% [markdown]
# ## **Installing libraries**

# %% [markdown]
# Install the ChEMBL web service package so that we can retrieve bioactivity data from the ChEMBL Database.

# %%
! pip install chembl_webresource_client
# Out:
# Requirement already satisfied: chembl_webresource_client in /home/chibeg/miniconda3/lib/python3.12/site-packages (0.10.9)
# Requirement already satisfied: urllib3 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (2.1.0)
# Requirement already satisfied: requests>=2.18.4 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (2.31.0)
# Requirement already satisfied: requests-cache~=1.2 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (1.2.0)
# Requirement already satisfied: easydict in /home/chibeg/miniconda3/lib/python3.12/site-packages (from chembl_webresource_client) (1.13)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests>=2.18.4->chembl_webresource_client) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests>=2.18.4->chembl_webresource_client) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests>=2.18.4->chembl_webresource_client) (2024.2.2)
# Requirement already satisfied: attrs>=21.2 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.0)
# Requirement already satisfied: cattrs>=22.2 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (23.2.3)
# Requirement already satisfied: platformdirs>=2.5 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (3.10.0)
# Requirement already satisfied: url-normalize>=1.4 in /home/chibeg/miniconda3/lib/python3.12/site-packages (from requests-cache~=1.2->chembl_webresource_client) (1.4.3)
# Requirement already satisfied: six in /home/chibeg/miniconda3/lib/python3.12/site-packages (from url-normalize>=1.4->requests-cache~=1.2->chembl_webresource_client) (1.16.0)

# %% [markdown]
# ## **Importing libraries**

# %%
# Import necessary libraries
import pandas as pd
from chembl_webresource_client.new_client import new_client

# %% [markdown]
# ## **Search for Target protein**

# %% [markdown]
# ### **Target search for Acetylcholinesterase**

# %%
# Target search for coronavirus
target = new_client.target
target_query = target.search('')
targets = pd.DataFrame.from_dict(target_query)
targets
# Out:
# ---------------------------------------------------------------------------
# gaierror                                  Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:156, in HTTPConnection._new_conn(self)
#     155 try:
# --> 156     conn = connection.create_connection(
#     157         (self._dns_host, self.port), self.timeout, **extra_kw
#     158     )
#     160 except SocketTimeout:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/util/connection.py:61, in create_connection(address, timeout, source_address, socket_options)
#      59 family = allowed_gai_family()
# ---> 61 for res in socket.getaddrinfo(host, port, family, socket.SOCK_STREAM):
#      62     af, socktype, proto, canonname, sa = res
#
# File /usr/lib/python3.10/socket.py:955, in getaddrinfo(host, port, family, type, proto, flags)
#     954 addrlist = []
# --> 955 for res in _socket.getaddrinfo(host, port, family, type, proto, flags):
#     956     af, socktype, proto, canonname, sa = res
#
# gaierror: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# NewConnectionError                        Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:665, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     664 # Make the request on the httplib connection object.
# --> 665 httplib_response = self._make_request(
#     666     conn,
#     667     method,
#     668     url,
#     669     timeout=timeout_obj,
#     670     body=body,
#     671     headers=headers,
#     672     chunked=chunked,
#     673 )
#     675 # If we're going to release the connection in ``finally:``, then
#     676 # the response doesn't need to know about the connection. Otherwise
#     677 # it will also try to release it and we'll have a double-release
#     678 # mess.
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:376, in HTTPConnectionPool._make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     375 try:
# --> 376     self._validate_conn(conn)
#     377 except (SocketTimeout, BaseSSLError) as e:
#     378     # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:994, in HTTPSConnectionPool._validate_conn(self, conn)
#     993 if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# --> 994     conn.connect()
#     996 if not conn.is_verified:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:334, in VerifiedHTTPSConnection.connect(self)
#     332 def connect(self):
#     333     # Add certificate verification
# --> 334     conn = self._new_conn()
#     335     hostname = self.host
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connection.py:168, in HTTPConnection._new_conn(self)
#     167 except SocketError as e:
# --> 168     raise NewConnectionError(
#     169         self, "Failed to establish a new connection: %s" % e
#     170     )
#     172 return conn
#
# NewConnectionError: <urllib3.connection.VerifiedHTTPSConnection object at 0x798c54d61ff0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution
#
# During handling of the above exception, another exception occurred:
#
# MaxRetryError                             Traceback (most recent call last)
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:486, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     485 try:
# --> 486     resp = conn.urlopen(
#     487         method=request.method,
#     488         url=url,
#     489         body=request.body,
#     490         headers=request.headers,
#     491         redirect=False,
#     492         assert_same_host=False,
#     493         preload_content=False,
#     494         decode_content=False,
#     495         retries=self.max_retries,
#     496         timeout=timeout,
#     497         chunked=chunked,
#     498     )
#     500 except (ProtocolError, OSError) as err:
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:750, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     744     log.warning(
#     745         "Retrying (%r) after connection " "broken by '%r': %s",
#     746         retries,
#     747         err,
#     748         url,
#     749     )
# --> 750     return self.urlopen(
#     751         method,
#     752         url,
#     753         body,
#     754         headers,
#     755         retries,
#     756         redirect,
#     757         assert_same_host,
#     758         timeout=timeout,
#     759         pool_timeout=pool_timeout,
#     760         release_conn=release_conn,
#     761         body_pos=body_pos,
#     762         **response_kw
#     763     )
#     765 def drain_and_release_conn(response):
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:750, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     744     log.warning(
#     745         "Retrying (%r) after connection " "broken by '%r': %s",
#     746         retries,
#     747         err,
#     748         url,
#     749     )
# --> 750     return self.urlopen(
#     751         method,
#     752         url,
#     753         body,
#     754         headers,
#     755         retries,
#     756         redirect,
#     757         assert_same_host,
#     758         timeout=timeout,
#     759         pool_timeout=pool_timeout,
#     760         release_conn=release_conn,
#     761         body_pos=body_pos,
#     762         **response_kw
#     763     )
#     765 def drain_and_release_conn(response):
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:750, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     744     log.warning(
#     745         "Retrying (%r) after connection " "broken by '%r': %s",
#     746         retries,
#     747         err,
#     748         url,
#     749     )
# --> 750     return self.urlopen(
#     751         method,
#     752         url,
#     753         body,
#     754         headers,
#     755         retries,
#     756         redirect,
#     757         assert_same_host,
#     758         timeout=timeout,
#     759         pool_timeout=pool_timeout,
#     760         release_conn=release_conn,
#     761         body_pos=body_pos,
#     762         **response_kw
#     763     )
#     765 def drain_and_release_conn(response):
#
# File ~/.local/lib/python3.10/site-packages/urllib3/connectionpool.py:719, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     717     e = ProtocolError("Connection aborted.", e)
# --> 719 retries = retries.increment(
#     720     method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#     721 )
#     722 retries.sleep()
#
# File ~/.local/lib/python3.10/site-packages/urllib3/util/retry.py:436, in Retry.increment(self, method, url, response, error, _pool, _stacktrace)
#     435 if new_retry.is_exhausted():
# --> 436     raise MaxRetryError(_pool, url, error or ResponseError(cause))
#     438 log.debug("Incremented Retry for (url='%s'): %r", url, new_retry)
#
# MaxRetryError: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Max retries exceeded with url: /chembl/api/data/target/search.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x798c54d61ff0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# Cell In[6], line 4
#       2 target = new_client.target
#       3 target_query = target.search('cancer')
# ----> 4 targets = pd.DataFrame.from_dict(target_query)
#       5 targets
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:1905, in DataFrame.from_dict(cls, data, orient, dtype, columns)
#    1899     raise ValueError(
#    1900         f"Expected 'index', 'columns' or 'tight' for orient parameter. "
#    1901         f"Got '{orient}' instead"
#    1902     )
#    1904 if orient != "tight":
# -> 1905     return cls(data, index=index, columns=columns, dtype=dtype)
#    1906 else:
#    1907     realdata = data["data"]
#
# File ~/.local/lib/python3.10/site-packages/pandas/core/frame.py:832, in DataFrame.__init__(self, data, index, columns, dtype, copy)
#     830         data = np.asarray(data)
#     831     else:
# --> 832         data = list(data)
#     833 if len(data) > 0:
#     834     if is_dataclass(data[0]):
#
# File ~/.local/lib/python3.10/site-packages/chembl_webresource_client/query_set.py:97, in QuerySet.__len__(self)
#      95 if not self.can_filter:
#      96     return 1
# ---> 97 return len(self.query)
#
# File ~/.local/lib/python3.10/site-packages/chembl_webresource_client/url_query.py:144, in UrlQuery.__len__(self)
#     142     return
#     143 if not self.api_total_count:
# --> 144     self.get_page()
#     145 return self.api_total_count
#
# File ~/.local/lib/python3.10/site-packages/chembl_webresource_client/url_query.py:389, in UrlQuery.get_page(self)
#     387 data = self._prepare_url_params()
#     388 with self._get_session() as session:
# --> 389     res = session.post(self.base_url + '.' + self.frmt, json=data, timeout=self.timeout)
#     390 self.logger.info(res.url)
#     391 self.logger.info(data)
#
# File ~/.local/lib/python3.10/site-packages/requests_cache/session.py:137, in CacheMixin.post(self, url, data, **kwargs)
#     136 def post(self, url: str, data=None, **kwargs) -> AnyResponse:  # type: ignore
# --> 137     return self.request('POST', url, data=data, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests_cache/session.py:182, in CacheMixin.request(self, method, url, headers, expire_after, only_if_cached, refresh, force_refresh, *args, **kwargs)
#     180 headers = set_request_headers(headers, expire_after, only_if_cached, refresh, force_refresh)
#     181 with patch_form_boundary() if kwargs.get('files') else nullcontext():
# --> 182     return super().request(method, url, *args, headers=headers, **kwargs)
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~/.local/lib/python3.10/site-packages/requests_cache/session.py:229, in CacheMixin.send(self, request, expire_after, only_if_cached, refresh, force_refresh, **kwargs)
#     227     response = self._resend(request, actions, cached_response, **kwargs)  # type: ignore
#     228 elif actions.send_request:
# --> 229     response = self._send_and_cache(request, actions, cached_response, **kwargs)
#     230 else:
#     231     response = cached_response  # type: ignore  # Guaranteed to be non-None by this point
#
# File ~/.local/lib/python3.10/site-packages/requests_cache/session.py:253, in CacheMixin._send_and_cache(self, request, actions, cached_response, **kwargs)
#     249 """Send a request and cache the response, unless disabled by settings or headers.
#     250 If applicable, also handle conditional requests.
#     251 """
#     252 request = actions.update_request(request)
# --> 253 response = super().send(request, **kwargs)
#     254 actions.update_from_response(response)
#     256 if not actions.skip_write:
#
# File ~/.local/lib/python3.10/site-packages/requests/sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~/.local/lib/python3.10/site-packages/requests/adapters.py:519, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     515     if isinstance(e.reason, _SSLError):
#     516         # This branch is for urllib3 v1.22 and later.
#     517         raise SSLError(e, request=request)
# --> 519     raise ConnectionError(e, request=request)
#     521 except ClosedPoolError as e:
#     522     raise ConnectionError(e, request=request)
#
# ConnectionError: HTTPSConnectionPool(host='www.ebi.ac.uk', port=443): Max retries exceeded with url: /chembl/api/data/target/search.json (Caused by NewConnectionError('<urllib3.connection.VerifiedHTTPSConnection object at 0x798c54d61ff0>: Failed to establish a new connection: [Errno -3] Temporary failure in name resolution'))

# %% [markdown]
# ### **Select and retrieve bioactivity data for *Human Acetylcholinesterase* (first entry)**

# %% [markdown]
# We will assign the fifth entry (which corresponds to the target protein, *Human Acetylcholinesterase*) to the ***selected_target*** variable

# %%
selected_target = targets.target_chembl_id[0]
selected_target
# Out:
# 'CHEMBL613732'

# %% [markdown]
# Here, we will retrieve only bioactivity data for *Human Acetylcholinesterase* (CHEMBL220) that are reported as pChEMBL values.

# %%
activity = new_client.activity
res = activity.filter(target_chembl_id=selected_target).filter(standard_type="IC50")

# %%
df = pd.DataFrame.from_dict(res)

# %%
df
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           33969                  []    CHEMBL643384
# 1           37563                  []    CHEMBL643384
# 2           37565                  []    CHEMBL643384
# 3           38902                  []    CHEMBL643384
# 4           41170                  []    CHEMBL643384
# ...           ...                 ...             ...
# 9086     25111481                  []   CHEMBL5265203
# 9087     25402914                  []   CHEMBL5303778
# 9088     25402962                  []   CHEMBL5303826
# 9089     25403899                  []   CHEMBL5303876
# 9090     25406273                  []   CHEMBL5304986
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 9086                Inhibition of AChE (unknown origin)          B
# 9087                              Cross screening panel          B
# 9088                              Cross screening panel          B
# 9089                              Cross screening panel          B
# 9090               Safety47 Scan (DiscoverX - Eurofins)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 9086                    None                   None  BAO_0000190  ...
# 9087                    None                   None  BAO_0000190  ...
# 9088                    None                   None  BAO_0000190  ...
# 9089                    None                   None  BAO_0000190  ...
# 9090                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0       Homo sapiens  Acetylcholinesterase          9606       None  None
# 1       Homo sapiens  Acetylcholinesterase          9606       None  None
# 2       Homo sapiens  Acetylcholinesterase          9606       None  None
# 3       Homo sapiens  Acetylcholinesterase          9606       None  None
# 4       Homo sapiens  Acetylcholinesterase          9606       None  None
# ...              ...                   ...           ...        ...   ...
# 9086    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9087    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9088    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9089    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9090    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value value
# 0      IC50    uM  UO_0000065        None  0.75
# 1      IC50    uM  UO_0000065        None   0.1
# 2      IC50    uM  UO_0000065        None  50.0
# 3      IC50    uM  UO_0000065        None   0.3
# 4      IC50    uM  UO_0000065        None   0.8
# ...     ...   ...         ...         ...   ...
# 9086   IC50    uM  UO_0000065        None  0.16
# 9087  pIC50  None  UO_0000065        None   5.1
# 9088  pIC50  None  UO_0000065        None   4.0
# 9089  pIC50  None  UO_0000065        None   4.2
# 9090   IC50    uM  UO_0000065        None  10.0
#
# [9091 rows x 46 columns]

# %% [markdown]
# Finally we will save the resulting bioactivity data to a CSV file **bioactivity_data.csv**.

# %%
df.to_csv('acetylcholinesterase_01_bioactivity_data_raw.csv', index=False)

# %% [markdown]
# ## **Handling missing data**
# If any compounds has missing value for the **standard_value** and **canonical_smiles** column then drop it.

# %%
df2 = df[df.standard_value.notna()]
df2 = df2[df.canonical_smiles.notna()]
df2
# Out:
# <ipython-input-13-955aac5800f0>:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   df2 = df2[df.canonical_smiles.notna()]
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           33969                  []    CHEMBL643384
# 1           37563                  []    CHEMBL643384
# 2           37565                  []    CHEMBL643384
# 3           38902                  []    CHEMBL643384
# 4           41170                  []    CHEMBL643384
# ...           ...                 ...             ...
# 9086     25111481                  []   CHEMBL5265203
# 9087     25402914                  []   CHEMBL5303778
# 9088     25402962                  []   CHEMBL5303826
# 9089     25403899                  []   CHEMBL5303876
# 9090     25406273                  []   CHEMBL5304986
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 9086                Inhibition of AChE (unknown origin)          B
# 9087                              Cross screening panel          B
# 9088                              Cross screening panel          B
# 9089                              Cross screening panel          B
# 9090               Safety47 Scan (DiscoverX - Eurofins)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 9086                    None                   None  BAO_0000190  ...
# 9087                    None                   None  BAO_0000190  ...
# 9088                    None                   None  BAO_0000190  ...
# 9089                    None                   None  BAO_0000190  ...
# 9090                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0       Homo sapiens  Acetylcholinesterase          9606       None  None
# 1       Homo sapiens  Acetylcholinesterase          9606       None  None
# 2       Homo sapiens  Acetylcholinesterase          9606       None  None
# 3       Homo sapiens  Acetylcholinesterase          9606       None  None
# 4       Homo sapiens  Acetylcholinesterase          9606       None  None
# ...              ...                   ...           ...        ...   ...
# 9086    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9087    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9088    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9089    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9090    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value value
# 0      IC50    uM  UO_0000065        None  0.75
# 1      IC50    uM  UO_0000065        None   0.1
# 2      IC50    uM  UO_0000065        None  50.0
# 3      IC50    uM  UO_0000065        None   0.3
# 4      IC50    uM  UO_0000065        None   0.8
# ...     ...   ...         ...         ...   ...
# 9086   IC50    uM  UO_0000065        None  0.16
# 9087  pIC50  None  UO_0000065        None   5.1
# 9088  pIC50  None  UO_0000065        None   4.0
# 9089  pIC50  None  UO_0000065        None   4.2
# 9090   IC50    uM  UO_0000065        None  10.0
#
# [7806 rows x 46 columns]

# %%
len(df2.canonical_smiles.unique())
# Out:
# 6369

# %%
df2_nr = df2.drop_duplicates(['canonical_smiles'])
df2_nr
# Out:
#                                             action_type activity_comment  \
# 0                                                  None             None
# 1                                                  None             None
# 2                                                  None             None
# 3                                                  None             None
# 4                                                  None             None
# ...                                                 ...              ...
# 9086  {'action_type': 'INHIBITOR', 'description': 'N...             None
# 9087                                               None             None
# 9088                                               None             None
# 9089                                               None             None
# 9090  {'action_type': 'INHIBITOR', 'description': 'N...             None
#
#       activity_id activity_properties assay_chembl_id  \
# 0           33969                  []    CHEMBL643384
# 1           37563                  []    CHEMBL643384
# 2           37565                  []    CHEMBL643384
# 3           38902                  []    CHEMBL643384
# 4           41170                  []    CHEMBL643384
# ...           ...                 ...             ...
# 9086     25111481                  []   CHEMBL5265203
# 9087     25402914                  []   CHEMBL5303778
# 9088     25402962                  []   CHEMBL5303826
# 9089     25403899                  []   CHEMBL5303876
# 9090     25406273                  []   CHEMBL5304986
#
#                                       assay_description assay_type  \
# 0     Inhibitory concentration against acetylcholine...          B
# 1     Inhibitory concentration against acetylcholine...          B
# 2     Inhibitory concentration against acetylcholine...          B
# 3     Inhibitory concentration against acetylcholine...          B
# 4     Inhibitory concentration against acetylcholine...          B
# ...                                                 ...        ...
# 9086                Inhibition of AChE (unknown origin)          B
# 9087                              Cross screening panel          B
# 9088                              Cross screening panel          B
# 9089                              Cross screening panel          B
# 9090               Safety47 Scan (DiscoverX - Eurofins)          B
#
#      assay_variant_accession assay_variant_mutation bao_endpoint  ...  \
# 0                       None                   None  BAO_0000190  ...
# 1                       None                   None  BAO_0000190  ...
# 2                       None                   None  BAO_0000190  ...
# 3                       None                   None  BAO_0000190  ...
# 4                       None                   None  BAO_0000190  ...
# ...                      ...                    ...          ...  ...
# 9086                    None                   None  BAO_0000190  ...
# 9087                    None                   None  BAO_0000190  ...
# 9088                    None                   None  BAO_0000190  ...
# 9089                    None                   None  BAO_0000190  ...
# 9090                    None                   None  BAO_0000190  ...
#
#      target_organism      target_pref_name target_tax_id text_value  toid  \
# 0       Homo sapiens  Acetylcholinesterase          9606       None  None
# 1       Homo sapiens  Acetylcholinesterase          9606       None  None
# 2       Homo sapiens  Acetylcholinesterase          9606       None  None
# 3       Homo sapiens  Acetylcholinesterase          9606       None  None
# 4       Homo sapiens  Acetylcholinesterase          9606       None  None
# ...              ...                   ...           ...        ...   ...
# 9086    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9087    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9088    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9089    Homo sapiens  Acetylcholinesterase          9606       None  None
# 9090    Homo sapiens  Acetylcholinesterase          9606       None  None
#
#        type units    uo_units upper_value value
# 0      IC50    uM  UO_0000065        None  0.75
# 1      IC50    uM  UO_0000065        None   0.1
# 2      IC50    uM  UO_0000065        None  50.0
# 3      IC50    uM  UO_0000065        None   0.3
# 4      IC50    uM  UO_0000065        None   0.8
# ...     ...   ...         ...         ...   ...
# 9086   IC50    uM  UO_0000065        None  0.16
# 9087  pIC50  None  UO_0000065        None   5.1
# 9088  pIC50  None  UO_0000065        None   4.0
# 9089  pIC50  None  UO_0000065        None   4.2
# 9090   IC50    uM  UO_0000065        None  10.0
#
# [6369 rows x 46 columns]

# %% [markdown]
# ## **Data pre-processing of the bioactivity data**

# %% [markdown]
# ### **Combine the 3 columns (molecule_chembl_id,canonical_smiles,standard_value) and bioactivity_class into a DataFrame**

# %%
selection = ['molecule_chembl_id','canonical_smiles','standard_value']
df3 = df2_nr[selection]
df3
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 9086      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 9087      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 9088      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 9089      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 9090      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#      standard_value
# 0             750.0
# 1             100.0
# 2           50000.0
# 3             300.0
# 4             800.0
# ...             ...
# 9086          160.0
# 9087        7943.28
# 9088       100000.0
# 9089       63095.73
# 9090        10000.0
#
# [6369 rows x 3 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df3.to_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv', index=False)

# %% [markdown]
# ### **Labeling compounds as either being active, inactive or intermediate**
# The bioactivity data is in the IC50 unit. Compounds having values of less than 1000 nM will be considered to be **active** while those greater than 10,000 nM will be considered to be **inactive**. As for those values in between 1,000 and 10,000 nM will be referred to as **intermediate**.

# %%
df4 = pd.read_csv('acetylcholinesterase_02_bioactivity_data_preprocessed.csv')

# %%
bioactivity_threshold = []
for i in df4.standard_value:
  if float(i) >= 10000:
    bioactivity_threshold.append("inactive")
  elif float(i) <= 1000:
    bioactivity_threshold.append("active")
  else:
    bioactivity_threshold.append("intermediate")

# %%
bioactivity_class = pd.Series(bioactivity_threshold, name='class')
df5 = pd.concat([df4, bioactivity_class], axis=1)
df5
# Out:
#      molecule_chembl_id                                   canonical_smiles  \
# 0          CHEMBL133897              CCOc1nn(-c2cccc(OCc3ccccc3)c2)c(=O)o1
# 1          CHEMBL336398         O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC1CC1
# 2          CHEMBL131588  CN(C(=O)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F)c1ccccc1
# 3          CHEMBL130628      O=C(N1CCCCC1)n1nc(-c2ccc(Cl)cc2)nc1SCC(F)(F)F
# 4          CHEMBL130478          CSc1nc(-c2ccc(OC(F)(F)F)cc2)nn1C(=O)N(C)C
# ...                 ...                                                ...
# 6364      CHEMBL2238282              O=C(/C=C/c1ccc(N2CCCCC2)cc1)c1sccc1Cl
# 6365      CHEMBL4636881  CC(=O)Nc1c(F)cc(C(=O)N[C@H]2CC[C@H](O)CC2)cc1O...
# 6366      CHEMBL4635134          CNC(=O)c1cc(C(=O)NC2CC2)cn(Cc2ccccc2)c1=O
# 6367      CHEMBL4639128  COCc1nc2cnc3cc(-c4c(C)noc4C)c(OC[C@H]4CCNC4)cc...
# 6368      CHEMBL5078078  CC(C)(O)c1ccc(N2Cc3c(ccnc3-c3ccc(F)cc3OCC(F)(F...
#
#       standard_value         class
# 0             750.00        active
# 1             100.00        active
# 2           50000.00      inactive
# 3             300.00        active
# 4             800.00        active
# ...              ...           ...
# 6364          160.00        active
# 6365         7943.28  intermediate
# 6366       100000.00      inactive
# 6367        63095.73      inactive
# 6368        10000.00      inactive
#
# [6369 rows x 4 columns]

# %% [markdown]
# Saves dataframe to CSV file

# %%
df5.to_csv('acetylcholinesterase_03_bioactivity_data_curated.csv', index=False)

# %%
! zip acetylcholinesterase.zip *.csv
# Out:
#   adding: acetylcholinesterase_01_bioactivity_data_raw.csv (deflated 91%)
#   adding: acetylcholinesterase_02_bioactivity_data_preprocessed.csv (deflated 80%)
#   adding: acetylcholinesterase_03_bioactivity_data_curated.csv (deflated 82%)

# %%
! ls -l
# Out:
# total 6692
# -rw-r--r-- 1 root root 5200159 Apr 24 13:57 acetylcholinesterase_01_bioactivity_data_raw.csv
# -rw-r--r-- 1 root root  468001 Apr 24 13:58 acetylcholinesterase_02_bioactivity_data_preprocessed.csv
# -rw-r--r-- 1 root root  526341 Apr 24 13:59 acetylcholinesterase_03_bioactivity_data_curated.csv
# -rw-r--r-- 1 root root  645598 Apr 24 13:59 acetylcholinesterase.zip
# drwxr-xr-x 1 root root    4096 Apr 22 13:25 sample_data

# %% [markdown]
# ---
